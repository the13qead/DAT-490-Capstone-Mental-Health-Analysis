# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# %%
# Mental Health Problems: Mood Swings, Increasing Stress, Mental Health History, and Social Weakness
# Independent Variables: Gender, Country, Occupation, SelfEmployed, FamilyHistory(?)
# Dependent Variables: HabitsChange, IncreasingStress, MoodSwings, SocialWeakness, CopingStruggles
# Uncategorized Variables: Treatment, DaysIndoors, MentalHealthHistory, WorkInterest, CareOptions
df = pd.read_csv('Mental_Health_dataset1.csv')
df.drop('SocialWeakness.1', axis=1, inplace=True)

independent_var = ['Gender','Country','Occupation','SelfEmployed','FamilyHistory']
dependent_var = ['IncreasingStress','SocialWeakness','MoodSwings','HabitsChange','WorkInterest','CopingStruggles']
mental_health_var = ['Treatment', 'MentalHealthInterview']
df
# Out:
#         Gender Country Occupation SelfEmployed FamilyHistory Treatment  \
# 0       Female      UK     Others           No           Yes        No
# 1       Female     USA  Housewife           No           Yes        No
# 2       Female  Canada     Others           No            No       Yes
# 3       Female  Canada  Corporate           No           Yes       Yes
# 4       Female      UK  Corporate           No            No       Yes
# ...        ...     ...        ...          ...           ...       ...
# 261323    Male     USA   Business           No            No        No
# 261324    Male     USA   Business          Yes           Yes       Yes
# 261325    Male     USA   Business           No           Yes        No
# 261326    Male     USA   Business           No           Yes       Yes
# 261327    Male     USA   Business           No           Yes       Yes
#
#                DaysIndoors HabitsChange MentalHealthHistory IncreasingStress  \
# 0               15-30 days           No                 Yes              Yes
# 1               15-30 days        Maybe               Maybe              Yes
# 2       More than 2 months        Maybe                  No               No
# 3         Go out Every day           No               Maybe               No
# 4       More than 2 months          Yes                  No            Maybe
# ...                    ...          ...                 ...              ...
# 261323          15-30 days        Maybe                  No               No
# 261324          15-30 days        Maybe                  No               No
# 261325          15-30 days        Maybe                  No               No
# 261326          15-30 days        Maybe                  No               No
# 261327          15-30 days        Maybe                  No               No
#
#        MoodSwings SocialWeakness CopingStruggles WorkInterest  \
# 0            High             No             Yes        Maybe
# 1            High          Maybe             Yes        Maybe
# 2          Medium             No              No           No
# 3          Medium             No              No        Maybe
# 4          Medium          Maybe              No        Maybe
# ...           ...            ...             ...          ...
# 261323        Low          Maybe             Yes           No
# 261324        Low          Maybe             Yes           No
# 261325        Low          Maybe             Yes           No
# 261326        Low          Maybe             Yes           No
# 261327        Low          Maybe             Yes           No
#
#        MentalHealthInterview CareOptions
# 0                         No          No
# 1                         No    Not sure
# 2                         No    Not sure
# 3                         No    Not sure
# 4                         No    Not sure
# ...                      ...         ...
# 261323                 Maybe    Not sure
# 261324                 Maybe    Not sure
# 261325                    No          No
# 261326                    No         Yes
# 261327                    No         Yes
#
# [261328 rows x 16 columns]

# %%
df.isnull().sum() # Check for null values
# Out:
# Gender                      0
# Country                     0
# Occupation                  0
# SelfEmployed             4356
# FamilyHistory               0
# Treatment                   0
# DaysIndoors                 0
# HabitsChange                0
# MentalHealthHistory         0
# IncreasingStress            0
# MoodSwings                  0
# SocialWeakness              0
# CopingStruggles             0
# WorkInterest                0
# MentalHealthInterview       0
# CareOptions                 0
# dtype: int64

# %%
# Remove null values
df = df.dropna()
df.isnull().sum()
# Out:
# Gender                   0
# Country                  0
# Occupation               0
# SelfEmployed             0
# FamilyHistory            0
# Treatment                0
# DaysIndoors              0
# HabitsChange             0
# MentalHealthHistory      0
# IncreasingStress         0
# MoodSwings               0
# SocialWeakness           0
# CopingStruggles          0
# WorkInterest             0
# MentalHealthInterview    0
# CareOptions              0
# dtype: int64

# %%
DaysIndoors = df['DaysIndoors'].unique()
Nationality = df['Country'].unique()
Occupation = df['Occupation'].unique()
MoodSwings = df['MoodSwings'].unique()
CareOptions = df['CareOptions'].unique()
Gender = df['Gender'].value_counts() # 230,614 male, 30,714 female
#df['SocialWeakness'].compare(df['SocialWeakness.1']) # RM SocialWeakness.1
Occupation
# Out:
# array(['Others', 'Housewife', 'Corporate', 'Student', 'Business'],
#       dtype=object)

# %%
HabitsChange_Values = df['HabitsChange'].value_counts()
Nationality_Values = df['Country'].value_counts() # Treat maybes like a 0.5?
HabitsChange_Values
# Out:
# HabitsChange
# Yes      96066
# Maybe    83654
# No       77252
# Name: count, dtype: int64

# %%
# Readjusted Nationality_Values to a 2D Array
Country_Values = np.array([Nationality_Values.index.tolist(), Nationality_Values.tolist()]).T
Country_Values
# Out:
# array([['USA', '151814'],
#        ['UK', '47110'],
#        ['Canada', '13253'],
#        ['Netherlands', '5639'],
#        ['Ireland', '5128'],
#        ['Germany', '4615'],
#        ['Australia', '3544'],
#        ['India', '2565'],
#        ['Sweden', '2414'],
#        ['France', '2306'],
#        ['South Africa', '1807'],
#        ['New Zealand', '1790'],
#        ['Italy', '1538'],
#        ['Switzerland', '1538'],
#        ['Israel', '1537'],
#        ['Brazil', '1338'],
#        ['Singapore', '770'],
#        ['Russia', '769'],
#        ['Greece', '768'],
#        ['Denmark', '766'],
#        ['Poland', '637'],
#        ['Belgium', '477'],
#        ['Nigeria', '385'],
#        ['Croatia', '385'],
#        ['Thailand', '385'],
#        ['Moldova', '385'],
#        ['Costa Rica', '384'],
#        ['Mexico', '384'],
#        ['Czech Republic', '384'],
#        ['Colombia', '384'],
#        ['Finland', '384'],
#        ['Portugal', '384'],
#        ['Georgia', '384'],
#        ['Philippines', '384'],
#        ['Bosnia and Herzegovina', '237']], dtype='<U22')

# %%
plt.bar(Nationality_Values.index.tolist(), Nationality_Values.tolist())
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.ylabel('Amount of Responses')
plt.title('Amount of Responses by Country')
plt.savefig('ResponsesByCountry.png')
plt.show()

# %%
df.describe(include='object')
# Out:
#         Gender Country Occupation SelfEmployed FamilyHistory Treatment  \
# count   256972  256972     256972       256972        256972    256972
# unique       2      35          5            2             2         2
# top       Male     USA  Housewife           No            No        No
# freq    227002  151814      59078       230404        159260    130882
#
#        DaysIndoors HabitsChange MentalHealthHistory IncreasingStress  \
# count       256972       256972              256972           256972
# unique           5            3                   3                3
# top      1-14 days          Yes                  No            Maybe
# freq         56628        96066               92472            89195
#
#        MoodSwings SocialWeakness CopingStruggles WorkInterest  \
# count      256972         256972          256972       256972
# unique          3              3               2            3
# top        Medium          Maybe              No           No
# freq        88731          91728          136962        92881
#
#        MentalHealthInterview CareOptions
# count                 256972      256972
# unique                     3           3
# top                       No          No
# freq                  203197      106970

# %%
# Chi-Squared Test
# Gender and Increasing Stress
contingency_table = pd.crosstab(df['Gender'], df['IncreasingStress'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print("Gender and Increasing Stress Table:")
print(contingency_table)
print(f"Chi Stat: {chi2}")
print(f"P-value: {p_value}")
# Out:
# Gender and Increasing Stress Table:
# IncreasingStress  Maybe     No    Yes
# Gender
# Female             9016   9037  11917
# Male              80179  71817  75006
# Chi Stat: 581.3048245265506
# P-value: 5.9055615763712765e-127

# %%
# Gender and Country
pd.set_option('display.max_columns', None) # Print whole table
c_table = pd.crosstab(df['Gender'], df['Country'])
print("Gender by Country:")
print(c_table)
pd.reset_option('display.max_columns') # Reset table settings
# Out:
# Gender by Country:
# Country  Australia  Belgium  Bosnia and Herzegovina  Brazil  Canada  Colombia  \
# Gender
# Female        1028      250                       0       0    2286         0
# Male          2516      227                     237    1338   10967       384
#
# Country  Costa Rica  Croatia  Czech Republic  Denmark  Finland  France  \
# Gender
# Female            0        0               0        0        0       0
# Male            384      385             384      766      384    2306
#
# Country  Georgia  Germany  Greece  India  Ireland  Israel  Italy  Mexico  \
# Gender
# Female         0        0       0    259      515       0      0       0
# Male         384     4615     768   2306     4613    1537   1538     384
#
# Country  Moldova  Netherlands  New Zealand  Nigeria  Philippines  Poland  \
# Gender
# Female         0          259          252        0            0     253
# Male         385         5380         1538      385          384     384
#
# Country  Portugal  Russia  Singapore  South Africa  Sweden  Switzerland  \
# Gender
# Female          0       0          0           270     492            0
# Male          384     769        770          1537    1922         1538
#
# Country  Thailand     UK     USA
# Gender
# Female          0   4074   20032
# Male          385  43036  131782

# %%
# Gender and Occupation
c_table = pd.crosstab(df['Gender'], df['Occupation'], normalize='index').mul(100).round(2)
print("Gender and Occupation by Percentage:")
print(c_table)
# Out:
# Gender and Occupation by Percentage:
# Occupation  Business  Corporate  Housewife  Others  Student
# Gender
# Female         18.36      16.96      22.21   19.81    22.65
# Male           16.63      21.86      23.09   17.93    20.49

# %%
# Occupation and Dependent Variables
for var in dependent_var:
    c_table = pd.crosstab(df['Occupation'], df[var], normalize='index').mul(100).round(2)
    print(f"Occupation and {var} by Percentage:")
    print(c_table)
    print()
# Out:
# Occupation and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Occupation
# Business          35.17  25.87  38.96
# Corporate         27.86  33.92  38.22
# Housewife         36.89  34.43  28.68
# Others            35.29  36.61  28.10
# Student           38.44  25.69  35.86
#
# Occupation and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Occupation
# Business        29.90  35.55  34.54
# Corporate       40.74  29.37  29.89
# Housewife       30.58  34.66  34.76
# Others          36.02  38.22  25.76
# Student         40.61  31.37  28.02
#
# Occupation and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Occupation
# Business    27.35  30.65   42.00
# Corporate   26.02  29.35   44.64
# Housewife   27.23  40.16   32.60
# Others      30.92  40.99   28.09
# Student     44.99  29.14   25.86
#
# Occupation and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Occupation
# Business      33.55  28.33  38.12
# Corporate     36.30  32.20  31.50
# Housewife     27.66  34.51  37.84
# Others        31.21  28.06  40.74
# Student       34.50  26.11  39.39
#
# Occupation and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Occupation
# Business      35.95  39.51  24.54
# Corporate     31.05  35.24  33.71
# Housewife     32.46  35.15  32.39
# Others        36.69  37.52  25.80
# Student       37.02  34.24  28.74
#
# Occupation and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Occupation
# Business         47.89  52.11
# Corporate        57.83  42.17
# Housewife        56.33  43.67
# Others           54.29  45.71
# Student          48.80  51.20

# %%
# Family History and Dependent Variables
for var in dependent_var:
    c_table = pd.crosstab(df['FamilyHistory'], df[var], normalize='index').mul(100).round(2)
    chi2, p_value, dof, expected = chi2_contingency(c_table)
    print(f"Family History and {var} by Percentage:")
    print(c_table)
    print()
    print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
    print()
# Out:
# Family History and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# FamilyHistory
# No                34.94  31.53  33.53
# Yes               34.34  31.36  34.30
#
# Chi Stat: 0.0144 | P-Value: 0.993 | Degrees of Freedom: 2 | Expected Frequencies: [[34.64 31.44 33.92]
#  [34.64 31.44 33.92]]
#
# Family History and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# FamilyHistory
# No              35.78  33.61  30.61
# Yes             35.56  33.71  30.73
#
# Chi Stat: 0.0011 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[35.67 33.66 30.67]
#  [35.67 33.66 30.67]]
#
# Family History and MoodSwings by Percentage:
# MoodSwings      High    Low  Medium
# FamilyHistory
# No             31.23  34.15   34.62
# Yes            31.54  34.07   34.38
#
# Chi Stat: 0.0025 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[31.39 34.11 34.5 ]
#  [31.38 34.11 34.5 ]]
#
# Family History and HabitsChange by Percentage:
# HabitsChange   Maybe     No    Yes
# FamilyHistory
# No             32.53  30.00  37.47
# Yes            32.59  30.16  37.25
#
# Chi Stat: 0.0011 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[32.56 30.08 37.36]
#  [32.56 30.08 37.36]]
#
# Family History and WorkInterest by Percentage:
# WorkInterest   Maybe     No    Yes
# FamilyHistory
# No             34.53  36.20  29.27
# Yes            34.35  36.05  29.59
#
# Chi Stat: 0.0025 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[34.44 36.13 29.43]
#  [34.44 36.12 29.43]]
#
# Family History and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# FamilyHistory
# No               53.58  46.42
# Yes              52.84  47.16
#
# Chi Stat: 0.0 | P-Value: 1.0 | Degrees of Freedom: 1 | Expected Frequencies: [[53.21 46.79]
#  [53.21 46.79]]

# %%
# Mental Health History and Days Indoors
c_table = pd.crosstab(df['MentalHealthHistory'], df['DaysIndoors'], normalize='index').mul(100).round(2)
print("Mental Health History and Days Indoors by Percentage:")
print(c_table)
# Out:
# Mental Health History and Days Indoors by Percentage:
# DaysIndoors          1-14 days  15-30 days  31-60 days  Go out Every day  \
# MentalHealthHistory
# Maybe                    19.29       16.99       25.12             16.64
# No                       26.16       15.68       19.66             21.36
# Yes                      20.17       21.74       18.41             22.08
#
# DaysIndoors          More than 2 months
# MentalHealthHistory
# Maybe                             21.96
# No                                17.14
# Yes                               17.60

# %%
# Mental Health History and Treatment
c_table = pd.crosstab(df['MentalHealthHistory'], df['Treatment'], normalize='index').mul(100).round(2)
print("Mental Health History and Treatment by Percentage:")
print(c_table)
# Out:
# Mental Health History and Treatment by Percentage:
# Treatment               No    Yes
# MentalHealthHistory
# Maybe                50.64  49.36
# No                   51.14  48.86
# Yes                  51.00  49.00

# %%
# Mental Health History and Dependent Variables
for var in dependent_var:
    c_table = pd.crosstab(df['MentalHealthHistory'], df[var], normalize='index').mul(100).round(2)
    chi2, p_value, dof, expected = chi2_contingency(c_table)
    print(f"Mental Health History and {var} by Percentage:")
    print(c_table)
    print()
    print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
    print()
# Out:
# Mental Health History and IncreasingStress by Percentage:
# IncreasingStress     Maybe     No    Yes
# MentalHealthHistory
# Maybe                34.93  31.01  34.05
# No                   35.47  32.76  31.77
# Yes                  33.61  30.45  35.94
#
# Chi Stat: 0.4023 | P-Value: 0.982 | Degrees of Freedom: 4 | Expected Frequencies: [[34.67 31.4  33.92]
#  [34.67 31.41 33.92]
#  [34.67 31.41 33.92]]
#
# Mental Health History and SocialWeakness by Percentage:
# SocialWeakness       Maybe     No    Yes
# MentalHealthHistory
# Maybe                39.05  31.61  29.34
# No                   34.29  31.26  34.45
# Yes                  33.84  38.48  27.68
#
# Chi Stat: 2.2644 | P-Value: 0.687 | Degrees of Freedom: 4 | Expected Frequencies: [[35.73 33.78 30.49]
#  [35.73 33.78 30.49]
#  [35.73 33.78 30.49]]
#
# Mental Health History and MoodSwings by Percentage:
# MoodSwings            High    Low  Medium
# MentalHealthHistory
# Maybe                30.93  39.91   29.16
# No                   31.48  32.94   35.58
# Yes                  31.63  29.50   38.87
#
# Chi Stat: 3.07 | P-Value: 0.546 | Degrees of Freedom: 4 | Expected Frequencies: [[31.35 34.12 34.54]
#  [31.35 34.12 34.54]
#  [31.35 34.12 34.54]]
#
# Mental Health History and HabitsChange by Percentage:
# HabitsChange         Maybe     No    Yes
# MentalHealthHistory
# Maybe                35.79  33.14  31.07
# No                   29.63  28.31  42.06
# Yes                  32.56  28.89  38.56
#
# Chi Stat: 2.7367 | P-Value: 0.603 | Degrees of Freedom: 4 | Expected Frequencies: [[32.66 30.11 37.23]
#  [32.66 30.11 37.23]
#  [32.66 30.12 37.23]]
#
# Mental Health History and WorkInterest by Percentage:
# WorkInterest         Maybe     No    Yes
# MentalHealthHistory
# Maybe                31.01  38.42  30.56
# No                   40.49  35.16  24.35
# Yes                  31.13  34.92  33.95
#
# Chi Stat: 3.5412 | P-Value: 0.472 | Degrees of Freedom: 4 | Expected Frequencies: [[34.21 36.16 29.62]
#  [34.21 36.17 29.62]
#  [34.21 36.17 29.62]]
#
# Mental Health History and CopingStruggles by Percentage:
# CopingStruggles         No    Yes
# MentalHealthHistory
# Maybe                57.31  42.69
# No                   51.06  48.94
# Yes                  51.71  48.29
#
# Chi Stat: 0.9489 | P-Value: 0.622 | Degrees of Freedom: 2 | Expected Frequencies: [[53.36 46.64]
#  [53.36 46.64]
#  [53.36 46.64]]

# %%
# Self Employed and Dependent Variables by Occupation
Occupation_list = Occupation.tolist()
for var in dependent_var:
    c_table = pd.crosstab(df['Occupation'], df[var], normalize='index').mul(100).round(2)
    chi2, p_value, dof, expected = chi2_contingency(c_table)
    print(f"Occupation and {var} by Percentage:")
    print(c_table)
    print()
    print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
    print()
# Out:
# Occupation and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Occupation
# Business          35.17  25.87  38.96
# Corporate         27.86  33.92  38.22
# Housewife         36.89  34.43  28.68
# Others            35.29  36.61  28.10
# Student           38.44  25.69  35.86
#
# Chi Stat: 8.493 | P-Value: 0.387 | Degrees of Freedom: 8 | Expected Frequencies: [[34.73 31.3  33.96]
#  [34.73 31.3  33.96]
#  [34.73 31.3  33.96]
#  [34.73 31.3  33.96]
#  [34.73 31.3  33.96]]
#
# Occupation and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Occupation
# Business        29.90  35.55  34.54
# Corporate       40.74  29.37  29.89
# Housewife       30.58  34.66  34.76
# Others          36.02  38.22  25.76
# Student         40.61  31.37  28.02
#
# Chi Stat: 6.5921 | P-Value: 0.581 | Degrees of Freedom: 8 | Expected Frequencies: [[35.57 33.83 30.59]
#  [35.57 33.83 30.59]
#  [35.57 33.83 30.59]
#  [35.57 33.83 30.59]
#  [35.57 33.83 30.59]]
#
# Occupation and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Occupation
# Business    27.35  30.65   42.00
# Corporate   26.02  29.35   44.64
# Housewife   27.23  40.16   32.60
# Others      30.92  40.99   28.09
# Student     44.99  29.14   25.86
#
# Chi Stat: 20.1518 | P-Value: 0.01 | Degrees of Freedom: 8 | Expected Frequencies: [[31.3  34.06 34.64]
#  [31.31 34.06 34.64]
#  [31.3  34.06 34.64]
#  [31.3  34.06 34.64]
#  [31.3  34.06 34.64]]
#
# Occupation and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Occupation
# Business      33.55  28.33  38.12
# Corporate     36.30  32.20  31.50
# Housewife     27.66  34.51  37.84
# Others        31.21  28.06  40.74
# Student       34.50  26.11  39.39
#
# Chi Stat: 4.2781 | P-Value: 0.831 | Degrees of Freedom: 8 | Expected Frequencies: [[32.64 29.84 37.52]
#  [32.64 29.84 37.52]
#  [32.65 29.84 37.52]
#  [32.65 29.84 37.52]
#  [32.64 29.84 37.52]]
#
# Occupation and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Occupation
# Business      35.95  39.51  24.54
# Corporate     31.05  35.24  33.71
# Housewife     32.46  35.15  32.39
# Others        36.69  37.52  25.80
# Student       37.02  34.24  28.74
#
# Chi Stat: 3.552 | P-Value: 0.895 | Degrees of Freedom: 8 | Expected Frequencies: [[34.63 36.33 29.04]
#  [34.63 36.33 29.04]
#  [34.63 36.33 29.04]
#  [34.64 36.33 29.04]
#  [34.63 36.33 29.04]]
#
# Occupation and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Occupation
# Business         47.89  52.11
# Corporate        57.83  42.17
# Housewife        56.33  43.67
# Others           54.29  45.71
# Student          48.80  51.20
#
# Chi Stat: 3.205 | P-Value: 0.524 | Degrees of Freedom: 4 | Expected Frequencies: [[53.03 46.97]
#  [53.03 46.97]
#  [53.03 46.97]
#  [53.03 46.97]
#  [53.03 46.97]]

# %%
# All Variables P-Value <= 0.05
all_comp = []
for ivar in independent_var:
    for dvar in dependent_var:
        c_table = pd.crosstab(df[ivar], df[dvar], normalize='index').mul(100).round(2)
        chi2, p_value, dof, expected = chi2_contingency(c_table)
        if p_value <= 1:
            all_comp.append(f"{ivar} and {dvar}")
            print(f"{ivar} and {dvar} by Percentage:")
            print(c_table)
            print()
            print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
            print()
print(all_comp)
# Out:
# Gender and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Gender
# Female            30.08  30.15  39.76
# Male              35.32  31.64  33.04
#
# Chi Stat: 1.0761 | P-Value: 0.584 | Degrees of Freedom: 2 | Expected Frequencies: [[32.7  30.89 36.4 ]
#  [32.7  30.9  36.4 ]]
#
# Gender and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Gender
# Female          34.08  34.35  31.57
# Male            35.91  33.56  30.53
#
# Chi Stat: 0.0745 | P-Value: 0.963 | Degrees of Freedom: 2 | Expected Frequencies: [[34.99 33.96 31.05]
#  [34.99 33.96 31.05]]
#
# Gender and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Gender
# Female      34.01  33.38   32.61
# Male        31.00  34.22   34.78
#
# Chi Stat: 0.2197 | P-Value: 0.896 | Degrees of Freedom: 2 | Expected Frequencies: [[32.51 33.8  33.7 ]
#  [32.51 33.8  33.7 ]]
#
# Gender and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Gender
# Female        32.80  31.04  36.16
# Male          32.52  29.93  37.55
#
# Chi Stat: 0.0476 | P-Value: 0.976 | Degrees of Freedom: 2 | Expected Frequencies: [[32.66 30.48 36.85]
#  [32.66 30.48 36.85]]
#
# Gender and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Gender
# Female        33.38  34.96  31.65
# Male          34.60  36.30  29.10
#
# Chi Stat: 0.1541 | P-Value: 0.926 | Degrees of Freedom: 2 | Expected Frequencies: [[33.99 35.63 30.37]
#  [33.99 35.63 30.38]]
#
# Gender and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Gender
# Female           46.95  53.05
# Male             54.14  45.86
#
# Chi Stat: 0.7664 | P-Value: 0.381 | Degrees of Freedom: 1 | Expected Frequencies: [[50.54 49.46]
#  [50.54 49.46]]
#
# Country and IncreasingStress by Percentage:
# IncreasingStress        Maybe     No    Yes
# Country
# Australia               34.09  30.53  35.38
# Belgium                 35.01  31.03  33.96
# Bosnia and Herzegovina  33.76  33.33  32.91
# Brazil                  36.25  30.57  33.18
# Canada                  34.22  31.72  34.06
# Colombia                35.16  31.77  33.07
# Costa Rica              35.42  31.51  33.07
# Croatia                 35.32  31.69  32.99
# Czech Republic          35.16  31.77  33.07
# Denmark                 35.25  31.59  33.16
# Finland                 35.42  31.51  33.07
# France                  35.34  31.61  33.04
# Georgia                 35.16  31.77  33.07
# Germany                 35.34  31.64  33.02
# Greece                  35.16  31.77  33.07
# India                   34.74  31.93  33.33
# Ireland                 34.77  31.55  33.68
# Israel                  35.33  31.62  33.05
# Italy                   35.31  31.66  33.03
# Mexico                  35.16  31.77  33.07
# Moldova                 35.32  31.69  32.99
# Netherlands             35.08  31.62  33.30
# New Zealand             34.19  31.34  34.47
# Nigeria                 35.32  31.69  32.99
# Philippines             35.16  31.77  33.07
# Poland                  33.91  31.24  34.85
# Portugal                35.42  31.51  33.07
# Russia                  35.37  31.60  33.03
# Singapore               35.32  31.69  32.99
# South Africa            34.53  31.65  33.81
# Sweden                  34.34  31.07  34.59
# Switzerland             35.31  31.66  33.03
# Thailand                35.32  31.69  32.99
# UK                      34.90  31.46  33.64
# USA                     34.62  31.44  33.94
#
# Chi Stat: 0.8537 | P-Value: 1.0 | Degrees of Freedom: 68 | Expected Frequencies: [[35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]
#  [35.01 31.58 33.4 ]]
#
# Country and SocialWeakness by Percentage:
# SocialWeakness          Maybe     No    Yes
# Country
# Australia               35.84  33.58  30.59
# Belgium                 36.27  31.87  31.87
# Bosnia and Herzegovina  39.24  32.07  28.69
# Brazil                  36.17  34.16  29.67
# Canada                  35.68  33.41  30.91
# Colombia                35.94  33.59  30.47
# Costa Rica              35.94  33.59  30.47
# Croatia                 35.84  33.51  30.65
# Czech Republic          35.94  33.59  30.47
# Denmark                 35.77  33.68  30.55
# Finland                 35.94  33.59  30.47
# France                  35.91  33.56  30.53
# Georgia                 35.94  33.59  30.47
# Germany                 35.86  33.54  30.60
# Greece                  35.94  33.59  30.47
# India                   35.75  33.65  30.60
# Ireland                 35.53  33.74  30.73
# Israel                  35.91  33.57  30.51
# Italy                   35.89  33.55  30.56
# Mexico                  35.94  33.59  30.47
# Moldova                 35.84  33.51  30.65
# Netherlands             35.77  33.61  30.63
# New Zealand             35.59  33.46  30.95
# Nigeria                 35.84  33.51  30.65
# Philippines             35.94  33.59  30.47
# Poland                  36.26  33.28  30.46
# Portugal                35.94  33.59  30.47
# Russia                  35.89  33.55  30.56
# Singapore               35.84  33.51  30.65
# South Africa            35.25  33.70  31.05
# Sweden                  35.87  33.26  30.86
# Switzerland             35.89  33.55  30.56
# Thailand                35.84  33.51  30.65
# UK                      35.70  33.67  30.63
# USA                     35.66  33.69  30.65
#
# Chi Stat: 0.7304 | P-Value: 1.0 | Degrees of Freedom: 68 | Expected Frequencies: [[35.96 33.49 30.56]
#  [35.96 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.48 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.96 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.48 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]
#  [35.95 33.49 30.56]]
#
# Country and MoodSwings by Percentage:
# MoodSwings               High    Low  Medium
# Country
# Australia               31.57  33.97   34.45
# Belgium                 32.29  30.40   37.32
# Bosnia and Herzegovina  32.49  33.33   34.18
# Brazil                  31.09  33.78   35.13
# Canada                  31.77  33.92   34.32
# Colombia                30.99  34.38   34.64
# Costa Rica              30.99  34.11   34.90
# Croatia                 30.91  34.29   34.81
# Czech Republic          30.99  34.38   34.64
# Denmark                 31.07  34.20   34.73
# Finland                 30.99  34.11   34.90
# France                  30.96  34.22   34.82
# Georgia                 30.99  34.38   34.64
# Germany                 30.94  34.28   34.78
# Greece                  30.99  34.38   34.64
# India                   31.23  34.15   34.62
# Ireland                 31.55  34.24   34.20
# Israel                  30.97  34.29   34.74
# Italy                   30.95  34.27   34.79
# Mexico                  30.99  34.38   34.64
# Moldova                 30.91  34.55   34.55
# Netherlands             31.21  34.28   34.51
# New Zealand             31.12  33.91   34.97
# Nigeria                 30.91  34.29   34.81
# Philippines             30.99  34.38   34.64
# Poland                  32.50  33.91   33.59
# Portugal                30.99  34.11   34.90
# Russia                  30.95  34.20   34.85
# Singapore               30.91  34.29   34.81
# South Africa            31.43  33.76   34.81
# Sweden                  31.57  33.97   34.47
# Switzerland             30.95  34.27   34.79
# Thailand                30.91  34.29   34.81
# UK                      31.19  34.13   34.67
# USA                     31.39  34.14   34.47
#
# Chi Stat: 0.9415 | P-Value: 1.0 | Degrees of Freedom: 68 | Expected Frequencies: [[31.21 34.05 34.72]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.21 34.05 34.72]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.05 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.22 34.06 34.73]
#  [31.21 34.05 34.72]
#  [31.22 34.05 34.73]]
#
# Country and HabitsChange by Percentage:
# HabitsChange            Maybe     No    Yes
# Country
# Australia               32.79  30.14  37.08
# Belgium                 32.49  28.30  39.20
# Bosnia and Herzegovina  27.85  32.07  40.08
# Brazil                  31.76  30.49  37.74
# Canada                  32.92  30.25  36.83
# Colombia                32.55  29.95  37.50
# Costa Rica              32.55  29.95  37.50
# Croatia                 32.47  29.87  37.66
# Czech Republic          32.55  29.95  37.50
# Denmark                 32.38  30.03  37.60
# Finland                 32.55  29.95  37.50
# France                  32.52  29.92  37.55
# Georgia                 32.55  29.95  37.50
# Germany                 32.48  29.90  37.62
# Greece                  32.55  29.95  37.50
# India                   32.55  30.10  37.35
# Ireland                 32.55  30.03  37.42
# Israel                  32.53  29.93  37.54
# Italy                   32.51  29.91  37.58
# Mexico                  32.55  29.95  37.50
# Moldova                 32.47  29.87  37.66
# Netherlands             32.42  30.06  37.52
# New Zealand             32.74  29.94  37.32
# Nigeria                 32.47  29.87  37.66
# Philippines             32.55  29.95  37.50
# Poland                  30.93  29.98  39.09
# Portugal                32.55  29.95  37.50
# Russia                  32.51  29.91  37.58
# Singapore               32.47  29.87  37.66
# South Africa            32.32  30.44  37.24
# Sweden                  32.48  29.95  37.57
# Switzerland             32.51  29.91  37.58
# Thailand                32.47  29.87  37.66
# UK                      32.51  30.03  37.46
# USA                     32.56  30.07  37.37
#
# Chi Stat: 1.3297 | P-Value: 1.0 | Degrees of Freedom: 68 | Expected Frequencies: [[32.34 30.01 37.66]
#  [32.33 30.   37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.   37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.34 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.   37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]
#  [32.33 30.01 37.66]]
#
# Country and WorkInterest by Percentage:
# WorkInterest            Maybe     No    Yes
# Country
# Australia               34.93  35.50  29.57
# Belgium                 36.06  33.96  29.98
# Bosnia and Herzegovina  36.71  37.55  25.74
# Brazil                  34.90  38.27  26.83
# Canada                  34.02  36.97  29.01
# Colombia                34.64  36.20  29.17
# Costa Rica              34.64  36.20  29.17
# Croatia                 34.55  36.36  29.09
# Czech Republic          34.64  36.20  29.17
# Denmark                 34.73  36.03  29.24
# Finland                 34.64  36.20  29.17
# France                  34.61  36.25  29.14
# Georgia                 34.64  36.20  29.17
# Germany                 34.58  36.29  29.12
# Greece                  34.64  36.20  29.17
# India                   34.85  35.98  29.16
# Ireland                 34.65  36.06  29.29
# Israel                  34.61  36.24  29.15
# Italy                   34.59  36.28  29.13
# Mexico                  34.64  36.20  29.17
# Moldova                 34.55  36.36  29.09
# Netherlands             34.56  36.19  29.24
# New Zealand             33.97  36.31  29.72
# Nigeria                 34.55  36.36  29.09
# Philippines             34.64  36.20  29.17
# Poland                  34.07  35.32  30.61
# Portugal                34.64  36.20  29.17
# Russia                  34.59  36.28  29.13
# Singapore               34.55  36.36  29.09
# South Africa            34.53  35.97  29.50
# Sweden                  34.38  35.92  29.70
# Switzerland             34.59  36.28  29.13
# Thailand                34.55  36.36  29.09
# UK                      34.50  36.14  29.36
# USA                     34.44  36.07  29.49
#
# Chi Stat: 1.3159 | P-Value: 1.0 | Degrees of Freedom: 68 | Expected Frequencies: [[34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.66 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.66 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.21 29.12]
#  [34.66 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.22 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]
#  [34.67 36.21 29.12]]
#
# Country and CopingStruggles by Percentage:
# CopingStruggles            No    Yes
# Country
# Australia               52.06  47.94
# Belgium                 49.48  50.52
# Bosnia and Herzegovina  56.12  43.88
# Brazil                  55.68  44.32
# Canada                  52.67  47.33
# Colombia                54.17  45.83
# Costa Rica              54.17  45.83
# Croatia                 54.03  45.97
# Czech Republic          54.17  45.83
# Denmark                 54.31  45.69
# Finland                 54.17  45.83
# France                  54.12  45.88
# Georgia                 54.17  45.83
# Germany                 54.13  45.87
# Greece                  54.17  45.83
# India                   53.61  46.39
# Ireland                 53.55  46.45
# Israel                  54.20  45.80
# Italy                   54.10  45.90
# Mexico                  54.17  45.83
# Moldova                 54.29  45.71
# Netherlands             53.91  46.09
# New Zealand             52.85  47.15
# Nigeria                 54.03  45.97
# Philippines             54.17  45.83
# Poland                  50.71  49.29
# Portugal                54.17  45.83
# Russia                  54.10  45.90
# Singapore               54.03  45.97
# South Africa            52.96  47.04
# Sweden                  52.61  47.39
# Switzerland             54.10  45.90
# Thailand                54.03  45.97
# UK                      53.54  46.46
# USA                     53.18  46.82
#
# Chi Stat: 1.9039 | P-Value: 1.0 | Degrees of Freedom: 34 | Expected Frequencies: [[53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]
#  [53.71 46.29]]
#
# Occupation and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Occupation
# Business          35.17  25.87  38.96
# Corporate         27.86  33.92  38.22
# Housewife         36.89  34.43  28.68
# Others            35.29  36.61  28.10
# Student           38.44  25.69  35.86
#
# Chi Stat: 8.493 | P-Value: 0.387 | Degrees of Freedom: 8 | Expected Frequencies: [[34.73 31.3  33.96]
#  [34.73 31.3  33.96]
#  [34.73 31.3  33.96]
#  [34.73 31.3  33.96]
#  [34.73 31.3  33.96]]
#
# Occupation and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Occupation
# Business        29.90  35.55  34.54
# Corporate       40.74  29.37  29.89
# Housewife       30.58  34.66  34.76
# Others          36.02  38.22  25.76
# Student         40.61  31.37  28.02
#
# Chi Stat: 6.5921 | P-Value: 0.581 | Degrees of Freedom: 8 | Expected Frequencies: [[35.57 33.83 30.59]
#  [35.57 33.83 30.59]
#  [35.57 33.83 30.59]
#  [35.57 33.83 30.59]
#  [35.57 33.83 30.59]]
#
# Occupation and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Occupation
# Business    27.35  30.65   42.00
# Corporate   26.02  29.35   44.64
# Housewife   27.23  40.16   32.60
# Others      30.92  40.99   28.09
# Student     44.99  29.14   25.86
#
# Chi Stat: 20.1518 | P-Value: 0.01 | Degrees of Freedom: 8 | Expected Frequencies: [[31.3  34.06 34.64]
#  [31.31 34.06 34.64]
#  [31.3  34.06 34.64]
#  [31.3  34.06 34.64]
#  [31.3  34.06 34.64]]
#
# Occupation and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Occupation
# Business      33.55  28.33  38.12
# Corporate     36.30  32.20  31.50
# Housewife     27.66  34.51  37.84
# Others        31.21  28.06  40.74
# Student       34.50  26.11  39.39
#
# Chi Stat: 4.2781 | P-Value: 0.831 | Degrees of Freedom: 8 | Expected Frequencies: [[32.64 29.84 37.52]
#  [32.64 29.84 37.52]
#  [32.65 29.84 37.52]
#  [32.65 29.84 37.52]
#  [32.64 29.84 37.52]]
#
# Occupation and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Occupation
# Business      35.95  39.51  24.54
# Corporate     31.05  35.24  33.71
# Housewife     32.46  35.15  32.39
# Others        36.69  37.52  25.80
# Student       37.02  34.24  28.74
#
# Chi Stat: 3.552 | P-Value: 0.895 | Degrees of Freedom: 8 | Expected Frequencies: [[34.63 36.33 29.04]
#  [34.63 36.33 29.04]
#  [34.63 36.33 29.04]
#  [34.64 36.33 29.04]
#  [34.63 36.33 29.04]]
#
# Occupation and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Occupation
# Business         47.89  52.11
# Corporate        57.83  42.17
# Housewife        56.33  43.67
# Others           54.29  45.71
# Student          48.80  51.20
#
# Chi Stat: 3.205 | P-Value: 0.524 | Degrees of Freedom: 4 | Expected Frequencies: [[53.03 46.97]
#  [53.03 46.97]
#  [53.03 46.97]
#  [53.03 46.97]
#  [53.03 46.97]]
#
# SelfEmployed and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# SelfEmployed
# No                34.67  31.46  33.87
# Yes               35.02  31.52  33.47
#
# Chi Stat: 0.0042 | P-Value: 0.998 | Degrees of Freedom: 2 | Expected Frequencies: [[34.84 31.49 33.67]
#  [34.85 31.49 33.67]]
#
# SelfEmployed and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# SelfEmployed
# No              35.68  33.67  30.65
# Yes             35.79  33.48  30.72
#
# Chi Stat: 0.0008 | P-Value: 1.0 | Degrees of Freedom: 2 | Expected Frequencies: [[35.74 33.58 30.69]
#  [35.73 33.57 30.68]]
#
# SelfEmployed and MoodSwings by Percentage:
# MoodSwings     High    Low  Medium
# SelfEmployed
# No            31.36  34.12   34.52
# Yes           31.19  34.17   34.64
#
# Chi Stat: 0.0007 | P-Value: 1.0 | Degrees of Freedom: 2 | Expected Frequencies: [[31.28 34.14 34.58]
#  [31.28 34.14 34.58]]
#
# SelfEmployed and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# SelfEmployed
# No            32.56  30.05  37.39
# Yes           32.50  30.14  37.36
#
# Chi Stat: 0.0002 | P-Value: 1.0 | Degrees of Freedom: 2 | Expected Frequencies: [[32.53 30.1  37.38]
#  [32.53 30.1  37.38]]
#
# SelfEmployed and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# SelfEmployed
# No            34.45  36.14  29.41
# Yes           34.57  36.18  29.25
#
# Chi Stat: 0.0007 | P-Value: 1.0 | Degrees of Freedom: 2 | Expected Frequencies: [[34.51 36.16 29.33]
#  [34.51 36.16 29.33]]
#
# SelfEmployed and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# SelfEmployed
# No               53.24  46.76
# Yes              53.78  46.22
#
# Chi Stat: 0.0 | P-Value: 1.0 | Degrees of Freedom: 1 | Expected Frequencies: [[53.51 46.49]
#  [53.51 46.49]]
#
# FamilyHistory and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# FamilyHistory
# No                34.94  31.53  33.53
# Yes               34.34  31.36  34.30
#
# Chi Stat: 0.0144 | P-Value: 0.993 | Degrees of Freedom: 2 | Expected Frequencies: [[34.64 31.44 33.92]
#  [34.64 31.44 33.92]]
#
# FamilyHistory and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# FamilyHistory
# No              35.78  33.61  30.61
# Yes             35.56  33.71  30.73
#
# Chi Stat: 0.0011 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[35.67 33.66 30.67]
#  [35.67 33.66 30.67]]
#
# FamilyHistory and MoodSwings by Percentage:
# MoodSwings      High    Low  Medium
# FamilyHistory
# No             31.23  34.15   34.62
# Yes            31.54  34.07   34.38
#
# Chi Stat: 0.0025 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[31.39 34.11 34.5 ]
#  [31.38 34.11 34.5 ]]
#
# FamilyHistory and HabitsChange by Percentage:
# HabitsChange   Maybe     No    Yes
# FamilyHistory
# No             32.53  30.00  37.47
# Yes            32.59  30.16  37.25
#
# Chi Stat: 0.0011 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[32.56 30.08 37.36]
#  [32.56 30.08 37.36]]
#
# FamilyHistory and WorkInterest by Percentage:
# WorkInterest   Maybe     No    Yes
# FamilyHistory
# No             34.53  36.20  29.27
# Yes            34.35  36.05  29.59
#
# Chi Stat: 0.0025 | P-Value: 0.999 | Degrees of Freedom: 2 | Expected Frequencies: [[34.44 36.13 29.43]
#  [34.44 36.12 29.43]]
#
# FamilyHistory and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# FamilyHistory
# No               53.58  46.42
# Yes              52.84  47.16
#
# Chi Stat: 0.0 | P-Value: 1.0 | Degrees of Freedom: 1 | Expected Frequencies: [[53.21 46.79]
#  [53.21 46.79]]
#
# ['Gender and IncreasingStress', 'Gender and SocialWeakness', 'Gender and MoodSwings', 'Gender and HabitsChange', 'Gender and WorkInterest', 'Gender and CopingStruggles', 'Country and IncreasingStress', 'Country and SocialWeakness', 'Country and MoodSwings', 'Country and HabitsChange', 'Country and WorkInterest', 'Country and CopingStruggles', 'Occupation and IncreasingStress', 'Occupation and SocialWeakness', 'Occupation and MoodSwings', 'Occupation and HabitsChange', 'Occupation and WorkInterest', 'Occupation and CopingStruggles', 'SelfEmployed and IncreasingStress', 'SelfEmployed and SocialWeakness', 'SelfEmployed and MoodSwings', 'SelfEmployed and HabitsChange', 'SelfEmployed and WorkInterest', 'SelfEmployed and CopingStruggles', 'FamilyHistory and IncreasingStress', 'FamilyHistory and SocialWeakness', 'FamilyHistory and MoodSwings', 'FamilyHistory and HabitsChange', 'FamilyHistory and WorkInterest', 'FamilyHistory and CopingStruggles']

# %%
# Dataframe with countries with male and female respondents
NoFemCountries = ['Bosnia and Herzegovina', 'Brazil', 'Colombia', 'Costa Rica', 'Croatia', 'Czech Republic', 'Denmark', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Israel', 'Italy', 'Mexico', 'Moldova', 'Nigeria', 'Philippines', 'Portugal', 'Russia', 'Singapore', 'Switzerland', 'Thailand']
mf_df = df[~df['Country'].isin(NoFemCountries)]
mf_df
# Out:
#         Gender Country Occupation SelfEmployed FamilyHistory Treatment  \
# 0       Female      UK     Others           No           Yes        No
# 1       Female     USA  Housewife           No           Yes        No
# 2       Female  Canada     Others           No            No       Yes
# 3       Female  Canada  Corporate           No           Yes       Yes
# 4       Female      UK  Corporate           No            No       Yes
# ...        ...     ...        ...          ...           ...       ...
# 261323    Male     USA   Business           No            No        No
# 261324    Male     USA   Business          Yes           Yes       Yes
# 261325    Male     USA   Business           No           Yes        No
# 261326    Male     USA   Business           No           Yes       Yes
# 261327    Male     USA   Business           No           Yes       Yes
#
#                DaysIndoors HabitsChange MentalHealthHistory IncreasingStress  \
# 0               15-30 days           No                 Yes              Yes
# 1               15-30 days        Maybe               Maybe              Yes
# 2       More than 2 months        Maybe                  No               No
# 3         Go out Every day           No               Maybe               No
# 4       More than 2 months          Yes                  No            Maybe
# ...                    ...          ...                 ...              ...
# 261323          15-30 days        Maybe                  No               No
# 261324          15-30 days        Maybe                  No               No
# 261325          15-30 days        Maybe                  No               No
# 261326          15-30 days        Maybe                  No               No
# 261327          15-30 days        Maybe                  No               No
#
#        MoodSwings SocialWeakness CopingStruggles WorkInterest  \
# 0            High             No             Yes        Maybe
# 1            High          Maybe             Yes        Maybe
# 2          Medium             No              No           No
# 3          Medium             No              No        Maybe
# 4          Medium          Maybe              No        Maybe
# ...           ...            ...             ...          ...
# 261323        Low          Maybe             Yes           No
# 261324        Low          Maybe             Yes           No
# 261325        Low          Maybe             Yes           No
# 261326        Low          Maybe             Yes           No
# 261327        Low          Maybe             Yes           No
#
#        MentalHealthInterview CareOptions
# 0                         No          No
# 1                         No    Not sure
# 2                         No    Not sure
# 3                         No    Not sure
# 4                         No    Not sure
# ...                      ...         ...
# 261323                 Maybe    Not sure
# 261324                 Maybe    Not sure
# 261325                    No          No
# 261326                    No         Yes
# 261327                    No         Yes
#
# [236178 rows x 16 columns]

# %%
# All Variables F&M Only P-Value <= 0.05
all_comp = []
for ivar in independent_var:
    for dvar in dependent_var:
        c_table = pd.crosstab(mf_df[ivar], mf_df[dvar])
        chi2, p_value, dof, expected = chi2_contingency(c_table)
        if p_value <= 0.05:
            all_comp.append(f"{ivar} and {dvar}")
            print(f"{ivar} and {dvar} by Percentage:")
            print(c_table)
            print()
            print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
            print()
print(all_comp)
# Out:
# Gender and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Gender
# Female             9016   9037  11917
# Male              72828  65246  68134
#
# Chi Stat: 574.095 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[10385.66  9426.2  10158.14]
#  [71458.34 64856.8  69892.86]]
#
# Gender and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Gender
# Female          10213  10295   9462
# Male            74041  69189  62978
#
# Chi Stat: 38.5379 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[10691.48 10086.19  9192.33]
#  [73562.52 69397.81 63247.67]]
#
# Gender and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Gender
# Female      10193  10003    9774
# Male        63917  70567   71724
#
# Chi Stat: 116.9394 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 9404.25 10224.   10341.76]
#  [64705.75 70346.   71156.24]]
#
# Gender and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Gender
# Female         9830   9303  10837
# Male          67086  61715  77407
#
# Chi Stat: 24.6548 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 9760.32  9011.89 11197.79]
#  [67155.68 62006.11 77046.21]]
#
# Gender and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Gender
# Female        10005  10478   9487
# Male          71345  74833  60030
#
# Chi Stat: 81.5195 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[10322.97 10825.61  8821.42]
#  [71027.03 74485.39 60695.58]]
#
# Gender and CopingStruggles by Percentage:
# CopingStruggles      No    Yes
# Gender
# Female            14072  15898
# Male             111608  94600
#
# Chi Stat: 540.0859 | P-Value: 0.0 | Degrees of Freedom: 1 | Expected Frequencies: [[ 15948.27  14021.73]
#  [109731.73  96476.27]]
#
# Occupation and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Occupation
# Business          13986  10328  15504
# Corporate         13992  16985  19182
# Housewife         19997  18631  15644
# Others            15106  15676  12130
# Student           18763  12663  17591
#
# Chi Stat: 3841.0347 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[13798.34 12523.61 13496.05]
#  [17381.86 15776.07 17001.07]
#  [18807.16 17069.7  18395.14]
#  [14870.52 13496.74 14544.74]
#  [16986.12 15416.89 16613.99]]
#
# Occupation and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Occupation
# Business        11908  14145  13765
# Corporate       20395  14766  14998
# Housewife       16656  18798  18818
# Others          15449  16366  11097
# Student         19846  15409  13762
#
# Chi Stat: 2990.4738 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[14204.65 13400.46 12212.89]
#  [17893.69 16880.65 15384.66]
#  [19360.96 18264.85 16646.19]
#  [15308.4  14441.72 13161.87]
#  [17486.3  16496.32 15034.39]]
#
# Occupation and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Occupation
# Business    10916  12241   16661
# Corporate   13096  14699   22364
# Housewife   14841  21746   17685
# Others      13288  17551   12073
# Student     21969  14333   12715
#
# Chi Stat: 9409.4365 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[12494.44 13583.55 13740.01]
#  [15739.33 17111.29 17308.38]
#  [17029.94 18514.4  18727.65]
#  [13465.3  14639.04 14807.65]
#  [15380.98 16721.71 16914.31]]
#
# Occupation and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Occupation
# Business      13340  11285  15193
# Corporate     18186  16149  15824
# Housewife     15042  18699  20531
# Others        13428  12054  17430
# Student       16920  12831  19266
#
# Chi Stat: 2091.2047 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[12967.51 11973.15 14877.34]
#  [16335.26 15082.66 18741.08]
#  [17674.74 16319.42 20277.83]
#  [13975.13 12903.51 16033.36]
#  [15963.35 14739.26 18314.39]]
#
# Occupation and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Occupation
# Business      14315  15685   9818
# Corporate     15574  17649  16936
# Housewife     17611  19091  17570
# Others        15702  16090  11120
# Student       18148  16796  14073
#
# Chi Stat: 1598.5754 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[13715.06 14382.85 11720.09]
#  [17276.95 18118.18 14763.88]
#  [18693.64 19603.85 15974.5 ]
#  [14780.76 15500.45 12630.78]
#  [16883.59 17705.67 14427.74]]
#
# Occupation and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Occupation
# Business         19035  20783
# Corporate        28980  21179
# Housewife        30514  23758
# Others           23223  19689
# Student          23928  25089
#
# Chi Stat: 1479.73 | P-Value: 0.0 | Degrees of Freedom: 4 | Expected Frequencies: [[21188.79 18629.21]
#  [26691.66 23467.34]
#  [28880.36 25391.64]
#  [22835.24 20076.76]
#  [26083.96 22933.04]]
#
# FamilyHistory and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# FamilyHistory
# No                50162  45342  48280
# Yes               31682  28941  31771
#
# Chi Stat: 17.4252 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[49826.22 45223.12 48734.65]
#  [32017.78 29059.88 31316.35]]
#
# FamilyHistory and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# FamilyHistory
# No               76933  66851
# Yes              48747  43647
#
# Chi Stat: 12.5445 | P-Value: 0.0 | Degrees of Freedom: 1 | Expected Frequencies: [[76513.36 67270.64]
#  [49166.64 43227.36]]
#
# ['Gender and IncreasingStress', 'Gender and SocialWeakness', 'Gender and MoodSwings', 'Gender and HabitsChange', 'Gender and WorkInterest', 'Gender and CopingStruggles', 'Occupation and IncreasingStress', 'Occupation and SocialWeakness', 'Occupation and MoodSwings', 'Occupation and HabitsChange', 'Occupation and WorkInterest', 'Occupation and CopingStruggles', 'FamilyHistory and IncreasingStress', 'FamilyHistory and CopingStruggles']

# %%
# Are mf countries similar enough to all countries? 
mf = ['Gender and IncreasingStress', 'Gender and SocialWeakness', 'Gender and MoodSwings', 'Gender and HabitsChange', 'Gender and WorkInterest', 'Gender and CopingStruggles', 'Occupation and IncreasingStress', 'Occupation and SocialWeakness', 'Occupation and MoodSwings', 'Occupation and HabitsChange', 'Occupation and WorkInterest', 'Occupation and CopingStruggles', 'FamilyHistory and IncreasingStress', 'FamilyHistory and CopingStruggles']
nomf = ['Gender and IncreasingStress', 'Gender and SocialWeakness', 'Gender and MoodSwings', 'Gender and HabitsChange', 'Gender and WorkInterest', 'Gender and CopingStruggles', 'Occupation and IncreasingStress', 'Occupation and SocialWeakness', 'Occupation and MoodSwings', 'Occupation and HabitsChange', 'Occupation and WorkInterest', 'Occupation and CopingStruggles', 'FamilyHistory and IncreasingStress', 'FamilyHistory and CopingStruggles']
print(mf == nomf)
# Out:
# True

# %%
# Family History Analysis
c_table = pd.crosstab(df['FamilyHistory'], df['MoodSwings'])
chi2, p_value, dof, expected = chi2_contingency(c_table)
print(c_table)
print(f"CHI: {chi2} | P-VAL: {p_value}")
# Out:
# MoodSwings      High    Low  Medium
# FamilyHistory
# No             49733  54394   55133
# Yes            30820  33294   33598
# CHI: 2.977814674629817 | P-VAL: 0.22561904641693148

# %%
# Self Employed Analysis
se_df = df[df['SelfEmployed'] == 'Yes']
se_df
# Out:
#         Gender       Country Occupation SelfEmployed FamilyHistory Treatment  \
# 27      Female        Canada     Others          Yes           Yes       Yes
# 43      Female        Canada     Others          Yes           Yes       Yes
# 46      Female  South Africa     Others          Yes           Yes       Yes
# 59      Female  South Africa    Student          Yes           Yes       Yes
# 89      Female        Canada  Housewife          Yes           Yes       Yes
# ...        ...           ...        ...          ...           ...       ...
# 261241    Male           USA   Business          Yes           Yes       Yes
# 261248    Male           USA   Business          Yes            No        No
# 261278    Male           USA   Business          Yes            No       Yes
# 261289    Male           USA   Business          Yes           Yes       Yes
# 261324    Male           USA   Business          Yes           Yes       Yes
#
#                DaysIndoors HabitsChange MentalHealthHistory IncreasingStress  \
# 27      More than 2 months        Maybe               Maybe              Yes
# 43      More than 2 months           No                  No              Yes
# 46              15-30 days        Maybe                  No            Maybe
# 59      More than 2 months           No               Maybe            Maybe
# 89               1-14 days        Maybe                 Yes              Yes
# ...                    ...          ...                 ...              ...
# 261241          15-30 days        Maybe                  No               No
# 261248          15-30 days        Maybe                  No               No
# 261278          15-30 days        Maybe                  No               No
# 261289          15-30 days        Maybe                  No               No
# 261324          15-30 days        Maybe                  No               No
#
#        MoodSwings SocialWeakness CopingStruggles WorkInterest  \
# 27           High            Yes             Yes        Maybe
# 43         Medium          Maybe             Yes        Maybe
# 46            Low          Maybe              No        Maybe
# 59            Low             No              No        Maybe
# 89            Low            Yes             Yes        Maybe
# ...           ...            ...             ...          ...
# 261241        Low          Maybe             Yes           No
# 261248        Low          Maybe             Yes           No
# 261278        Low          Maybe             Yes           No
# 261289        Low          Maybe             Yes           No
# 261324        Low          Maybe             Yes           No
#
#        MentalHealthInterview CareOptions
# 27                        No         Yes
# 43                     Maybe         Yes
# 46                        No         Yes
# 59                        No         Yes
# 89                        No         Yes
# ...                      ...         ...
# 261241                    No         Yes
# 261248                 Maybe         Yes
# 261278                    No         Yes
# 261289                    No    Not sure
# 261324                 Maybe    Not sure
#
# [26568 rows x 16 columns]

# %%
se_df['Gender'].value_counts()
# Out:
# Gender
# Male      24799
# Female     1769
# Name: count, dtype: int64

# %%
# All Variables (Of Self Employed People) P-Value <= 0.05
all_comp = []
for ivar in independent_var:
    for dvar in dependent_var:
        c_table = pd.crosstab(se_df[ivar], se_df[dvar])
        percentage_table = pd.crosstab(se_df[ivar], se_df[dvar], normalize='index').mul(100).round(2)
        chi2, p_value, dof, expected = chi2_contingency(c_table)
        if p_value <= 0.05:
            all_comp.append(f"{ivar} and {dvar}")
            print(f"{ivar} and {dvar} by Percentage:")
            print(c_table)
            print()
            print(percentage_table)
            print()
            print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
            print()
print(all_comp)
# Out:
# Gender and IncreasingStress by Percentage:
# IncreasingStress  Maybe    No   Yes
# Gender
# Female              533   537   699
# Male               8770  7837  8192
#
# IncreasingStress  Maybe     No    Yes
# Gender
# Female            30.13  30.36  39.51
# Male              35.36  31.60  33.03
#
# Chi Stat: 34.4534 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 619.43  557.57  592.  ]
#  [8683.57 7816.43 8299.  ]]
#
# Gender and SocialWeakness by Percentage:
# SocialWeakness  Maybe    No   Yes
# Gender
# Female            596   579   594
# Male             8914  8316  7569
#
# SocialWeakness  Maybe     No    Yes
# Gender
# Female          33.69  32.73  33.58
# Male            35.94  33.53  30.52
#
# Chi Stat: 7.6831 | P-Value: 0.021 | Degrees of Freedom: 2 | Expected Frequencies: [[ 633.21  592.26  543.52]
#  [8876.79 8302.74 7619.48]]
#
# Gender and MoodSwings by Percentage:
# MoodSwings  High   Low  Medium
# Gender
# Female       602   587     580
# Male        7685  8492    8622
#
# MoodSwings   High    Low  Medium
# Gender
# Female      34.03  33.18   32.79
# Male        30.99  34.24   34.77
#
# Chi Stat: 7.3106 | P-Value: 0.026 | Degrees of Freedom: 2 | Expected Frequencies: [[ 551.78  604.51  612.7 ]
#  [7735.22 8474.49 8589.3 ]]
#
# Gender and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Gender
# Female             840    929
# Male             13449  11350
#
# CopingStruggles     No    Yes
# Gender
# Female           47.48  52.52
# Male             54.23  45.77
#
# Chi Stat: 29.974 | P-Value: 0.0 | Degrees of Freedom: 1 | Expected Frequencies: [[  951.42   817.58]
#  [13337.58 11461.42]]
#
# Occupation and IncreasingStress by Percentage:
# IncreasingStress  Maybe    No   Yes
# Occupation
# Business           1559  1132  1733
# Corporate          1596  1950  2194
# Housewife          2264  2152  1709
# Others             1710  1766  1296
# Student            2174  1374  1959
#
# IncreasingStress  Maybe     No    Yes
# Occupation
# Business          35.24  25.59  39.17
# Corporate         27.80  33.97  38.22
# Housewife         36.96  35.13  27.90
# Others            35.83  37.01  27.16
# Student           39.48  24.95  35.57
#
# Chi Stat: 533.4559 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[1549.1  1394.41 1480.49]
#  [2009.91 1809.2  1920.9 ]
#  [2144.72 1930.55 2049.74]
#  [1670.95 1504.09 1596.95]
#  [1928.32 1735.76 1842.92]]
#
# Occupation and SocialWeakness by Percentage:
# SocialWeakness  Maybe    No   Yes
# Occupation
# Business         1321  1566  1537
# Corporate        2355  1665  1720
# Housewife        1838  2129  2158
# Others           1726  1838  1208
# Student          2270  1697  1540
#
# SocialWeakness  Maybe     No    Yes
# Occupation
# Business        29.86  35.40  34.74
# Corporate       41.03  29.01  29.97
# Housewife       30.01  34.76  35.23
# Others          36.17  38.52  25.31
# Student         41.22  30.82  27.96
#
# Chi Stat: 404.1576 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[1583.57 1481.16 1359.27]
#  [2054.63 1921.76 1763.61]
#  [2192.44 2050.66 1881.9 ]
#  [1708.13 1597.67 1466.19]
#  [1971.23 1843.75 1692.02]]
#
# Occupation and MoodSwings by Percentage:
# MoodSwings  High   Low  Medium
# Occupation
# Business    1198  1336    1890
# Corporate   1464  1698    2578
# Housewife   1642  2484    1999
# Others      1463  1984    1325
# Student     2520  1577    1410
#
# MoodSwings   High    Low  Medium
# Occupation
# Business    27.08  30.20   42.72
# Corporate   25.51  29.58   44.91
# Housewife   26.81  40.56   32.64
# Others      30.66  41.58   27.77
# Student     45.76  28.64   25.60
#
# Chi Stat: 1211.4888 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[1379.92 1511.8  1532.28]
#  [1790.4  1961.51 1988.09]
#  [1910.49 2093.08 2121.43]
#  [1488.47 1630.72 1652.81]
#  [1717.72 1881.89 1907.39]]
#
# Occupation and HabitsChange by Percentage:
# HabitsChange  Maybe    No   Yes
# Occupation
# Business       1492  1264  1668
# Corporate      2085  1857  1798
# Housewife      1689  2131  2305
# Others         1473  1337  1962
# Student        1896  1419  2192
#
# HabitsChange  Maybe     No    Yes
# Occupation
# Business      33.73  28.57  37.70
# Corporate     36.32  32.35  31.32
# Housewife     27.58  34.79  37.63
# Others        30.87  28.02  41.11
# Student       34.43  25.77  39.80
#
# Chi Stat: 265.8116 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[1437.87 1333.46 1652.67]
#  [1865.59 1730.12 2144.29]
#  [1990.72 1846.17 2288.11]
#  [1550.97 1438.35 1782.67]
#  [1789.86 1659.89 2057.25]]
#
# Occupation and WorkInterest by Percentage:
# WorkInterest  Maybe    No   Yes
# Occupation
# Business       1592  1764  1068
# Corporate      1781  2041  1918
# Housewife      2007  2141  1977
# Others         1767  1795  1210
# Student        2038  1872  1597
#
# WorkInterest  Maybe     No    Yes
# Occupation
# Business      35.99  39.87  24.14
# Corporate     31.03  35.56  33.41
# Housewife     32.77  34.96  32.28
# Others        37.03  37.62  25.36
# Student       37.01  33.99  29.00
#
# Chi Stat: 194.3669 | P-Value: 0.0 | Degrees of Freedom: 8 | Expected Frequencies: [[1529.45 1600.72 1293.83]
#  [1984.41 2076.88 1678.7 ]
#  [2117.51 2216.19 1791.3 ]
#  [1649.76 1726.63 1395.61]
#  [1903.86 1992.58 1610.56]]
#
# Occupation and CopingStruggles by Percentage:
# CopingStruggles    No   Yes
# Occupation
# Business         2136  2288
# Corporate        3337  2403
# Housewife        3494  2631
# Others           2644  2128
# Student          2678  2829
#
# CopingStruggles     No    Yes
# Occupation
# Business         48.28  51.72
# Corporate        58.14  41.86
# Housewife        57.04  42.96
# Others           55.41  44.59
# Student          48.63  51.37
#
# Chi Stat: 187.7398 | P-Value: 0.0 | Degrees of Freedom: 4 | Expected Frequencies: [[2379.35 2044.65]
#  [3087.13 2652.87]
#  [3294.19 2830.81]
#  [2566.51 2205.49]
#  [2961.82 2545.18]]
#
# FamilyHistory and CopingStruggles by Percentage:
# CopingStruggles    No   Yes
# FamilyHistory
# No               8827  7434
# Yes              5462  4845
#
# CopingStruggles     No    Yes
# FamilyHistory
# No               54.28  45.72
# Yes              52.99  47.01
#
# Chi Stat: 4.1725 | P-Value: 0.041 | Degrees of Freedom: 1 | Expected Frequencies: [[8745.61 7515.39]
#  [5543.39 4763.61]]
#
# ['Gender and IncreasingStress', 'Gender and SocialWeakness', 'Gender and MoodSwings', 'Gender and CopingStruggles', 'Occupation and IncreasingStress', 'Occupation and SocialWeakness', 'Occupation and MoodSwings', 'Occupation and HabitsChange', 'Occupation and WorkInterest', 'Occupation and CopingStruggles', 'FamilyHistory and CopingStruggles']

# %%
# Self Employed House Wives Vs. Non Self Employed House Wives?
sehw_df = df[(df['SelfEmployed'] == 'Yes') & (df['Occupation'] == 'Housewife')]
nsehw_df = df[(df['SelfEmployed'] == 'No') & (df['Occupation'] == 'Housewife')]
all_comp = []
print("Self Employed House Wives")
for ivar in independent_var:
    for dvar in dependent_var:
        c_table = pd.crosstab(sehw_df[ivar], sehw_df[dvar])
        percentage_table = pd.crosstab(se_df[ivar], se_df[dvar], normalize='index').mul(100).round(2)
        chi2, p_value, dof, expected = chi2_contingency(c_table)
        if p_value <= 0.05:
            all_comp.append(f"{ivar} and {dvar}")
            print(f"{ivar} and {dvar} by Percentage:")
            print(c_table)
            print()
            print(percentage_table)
            print()
            print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
            print()
print(all_comp)
print()
print("---------------------------------------------------------------------------------------------------------")
print("Non-Self Employed House Wives")
print()
all_comp = []
for ivar in independent_var:
    for dvar in dependent_var:
        c_table = pd.crosstab(nsehw_df[ivar], nsehw_df[dvar])
        percentage_table = pd.crosstab(se_df[ivar], se_df[dvar], normalize='index').mul(100).round(2)
        chi2, p_value, dof, expected = chi2_contingency(c_table)
        if p_value <= 0.05:
            all_comp.append(f"{ivar} and {dvar}")
            print(f"{ivar} and {dvar} by Percentage:")
            print(c_table)
            print()
            print(percentage_table)
            print()
            print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
            print()
# Out:
# Self Employed House Wives
# Gender and IncreasingStress by Percentage:
# IncreasingStress  Maybe    No   Yes
# Gender
# Female              116   107   159
# Male               2148  2045  1550
#
# IncreasingStress  Maybe     No    Yes
# Gender
# Female            30.13  30.36  39.51
# Male              35.36  31.60  33.03
#
# Chi Stat: 38.1712 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 141.2   134.21  106.59]
#  [2122.8  2017.79 1602.41]]
#
# Gender and SocialWeakness by Percentage:
# SocialWeakness  Maybe    No   Yes
# Gender
# Female            158   120   104
# Male             1680  2009  2054
#
# SocialWeakness  Maybe     No    Yes
# Gender
# Female          33.69  32.73  33.58
# Male            35.94  33.53  30.52
#
# Chi Stat: 26.2257 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 114.63  132.78  134.59]
#  [1723.37 1996.22 2023.41]]
#
# Gender and MoodSwings by Percentage:
# MoodSwings  High   Low  Medium
# Gender
# Female       146   113     123
# Male        1496  2371    1876
#
# MoodSwings   High    Low  Medium
# Gender
# Female      34.03  33.18   32.79
# Male        30.99  34.24   34.77
#
# Chi Stat: 31.9128 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 102.41  154.92  124.67]
#  [1539.59 2329.08 1874.33]]
#
# Gender and HabitsChange by Percentage:
# HabitsChange  Maybe    No   Yes
# Gender
# Female          125   116   141
# Male           1564  2015  2164
#
# HabitsChange  Maybe     No    Yes
# Gender
# Female        32.11  31.49  36.40
# Male          32.53  30.05  37.42
#
# Chi Stat: 6.2636 | P-Value: 0.044 | Degrees of Freedom: 2 | Expected Frequencies: [[ 105.34  132.9   143.76]
#  [1583.66 1998.1  2161.24]]
#
# Gender and CopingStruggles by Percentage:
# CopingStruggles    No   Yes
# Gender
# Female            185   197
# Male             3309  2434
#
# CopingStruggles     No    Yes
# Gender
# Female           47.48  52.52
# Male             54.23  45.77
#
# Chi Stat: 11.9694 | P-Value: 0.001 | Degrees of Freedom: 1 | Expected Frequencies: [[ 217.91  164.09]
#  [3276.09 2466.91]]
#
# ['Gender and IncreasingStress', 'Gender and SocialWeakness', 'Gender and MoodSwings', 'Gender and HabitsChange', 'Gender and CopingStruggles']
#
# ---------------------------------------------------------------------------------------------------------
# Non-Self Employed House Wives
#
# Gender and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No    Yes
# Gender
# Female             2113   1541   2620
# Male              17419  16646  12614
#
# IncreasingStress  Maybe     No    Yes
# Gender
# Female            30.13  30.36  39.51
# Male              35.36  31.60  33.03
#
# Chi Stat: 635.7092 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 2314.2   2154.84  1804.96]
#  [17217.8  16032.16 13429.04]]
#
# Gender and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# Gender
# Female           2521   2040   1713
# Male            13705  16308  16666
#
# SocialWeakness  Maybe     No    Yes
# Gender
# Female          33.69  32.73  33.58
# Male            35.94  33.53  30.52
#
# Chi Stat: 333.1679 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 1922.5   2173.92  2177.59]
#  [14303.5  16174.08 16201.41]]
#
# Gender and MoodSwings by Percentage:
# MoodSwings   High    Low  Medium
# Gender
# Female       2290   1955    2029
# Male        12157  19288   15234
#
# MoodSwings   High    Low  Medium
# Gender
# Female      34.03  33.18   32.79
# Male        30.99  34.24   34.77
#
# Chi Stat: 364.0896 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 1711.72  2516.92  2045.36]
#  [12735.28 18726.08 15217.64]]
#
# Gender and HabitsChange by Percentage:
# HabitsChange  Maybe     No    Yes
# Gender
# Female         1977   1959   2338
# Male          12673  16295  17711
#
# HabitsChange  Maybe     No    Yes
# Gender
# Female        32.11  31.49  36.40
# Male          32.53  30.05  37.42
#
# Chi Stat: 60.4826 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 1735.77  2162.78  2375.45]
#  [12914.23 16091.22 17673.55]]
#
# Gender and WorkInterest by Percentage:
# WorkInterest  Maybe     No    Yes
# Gender
# Female         1908   2431   1935
# Male          15264  16193  15222
#
# WorkInterest  Maybe    No    Yes
# Gender
# Female        34.09  34.6  31.32
# Male          34.61  36.3  29.10
#
# Chi Stat: 40.1551 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[ 2034.58  2206.62  2032.8 ]
#  [15137.42 16417.38 15124.2 ]]
#
# Gender and CopingStruggles by Percentage:
# CopingStruggles     No    Yes
# Gender
# Female            2958   3316
# Male             26828  19851
#
# CopingStruggles     No    Yes
# Gender
# Female           47.48  52.52
# Male             54.23  45.77
#
# Chi Stat: 239.2291 | P-Value: 0.0 | Degrees of Freedom: 1 | Expected Frequencies: [[ 3529.12  2744.88]
#  [26256.88 20422.12]]
#
# FamilyHistory and IncreasingStress by Percentage:
# IncreasingStress  Maybe     No   Yes
# FamilyHistory
# No                12208  11440  9276
# Yes                7324   6747  5958
#
# IncreasingStress  Maybe     No    Yes
# FamilyHistory
# No                35.39  31.55  33.05
# Yes               34.42  31.46  34.11
#
# Chi Stat: 15.6735 | P-Value: 0.0 | Degrees of Freedom: 2 | Expected Frequencies: [[12144.2  11307.93  9471.88]
#  [ 7387.8   6879.07  5762.12]]
#
# FamilyHistory and SocialWeakness by Percentage:
# SocialWeakness  Maybe     No    Yes
# FamilyHistory
# No               9961  11434  11529
# Yes              6265   6914   6850
#
# SocialWeakness  Maybe     No    Yes
# FamilyHistory
# No              35.98  33.55  30.47
# Yes             35.50  33.38  31.12
#
# Chi Stat: 6.8197 | P-Value: 0.033 | Degrees of Freedom: 2 | Expected Frequencies: [[10088.66 11408.03 11427.31]
#  [ 6137.34  6939.97  6951.69]]
#
# FamilyHistory and MoodSwings by Percentage:
# MoodSwings     High    Low  Medium
# FamilyHistory
# No             8858  13331   10735
# Yes            5589   7912    6528
#
# MoodSwings      High    Low  Medium
# FamilyHistory
# No             30.94  34.29   34.77
# Yes            31.59  33.99   34.42
#
# Chi Stat: 7.5936 | P-Value: 0.022 | Degrees of Freedom: 2 | Expected Frequencies: [[ 8982.55 13208.02 10733.42]
#  [ 5464.45  8034.98  6529.58]]

# %%
all_comp = []
for ivar in mental_health_var:
    for dvar in dependent_var:
        c_table = pd.crosstab(se_df[dvar], se_df[ivar])
        percentage_table = pd.crosstab(se_df[ivar], se_df[dvar], normalize='index').mul(100).round(2)
        chi2, p_value, dof, expected = chi2_contingency(c_table)
        if p_value <= 1:
            all_comp.append(f"{ivar} and {dvar}")
            print(f"{ivar} and {dvar} by Percentage:")
            print(c_table)
            print()
            print(percentage_table)
            print()
            print(f"Chi Stat: {chi2.round(4)} | P-Value: {p_value.round(3)} | Degrees of Freedom: {dof} | Expected Frequencies: {expected.round(2)}")
            print()
print(all_comp)
# Out:
# Treatment and IncreasingStress by Percentage:
# Treatment           No   Yes
# IncreasingStress
# Maybe             4274  5029
# No                3813  4561
# Yes               3976  4915
#
# IncreasingStress  Maybe     No    Yes
# Treatment
# No                35.43  31.61  32.96
# Yes               34.67  31.44  33.88
#
# Chi Stat: 2.825 | P-Value: 0.244 | Degrees of Freedom: 2 | Expected Frequencies: [[4223.96 5079.04]
#  [3802.15 4571.85]
#  [4036.89 4854.11]]
#
# Treatment and SocialWeakness by Percentage:
# Treatment         No   Yes
# SocialWeakness
# Maybe           4334  5176
# No              4043  4852
# Yes             3686  4477
#
# SocialWeakness  Maybe     No    Yes
# Treatment
# No              35.93  33.52  30.56
# Yes             35.68  33.45  30.87
#
# Chi Stat: 0.3223 | P-Value: 0.851 | Degrees of Freedom: 2 | Expected Frequencies: [[4317.94 5192.06]
#  [4038.71 4856.29]
#  [3706.35 4456.65]]
#
# Treatment and MoodSwings by Percentage:
# Treatment     No   Yes
# MoodSwings
# High        3743  4544
# Low         4120  4959
# Medium      4200  5002
#
# MoodSwings   High    Low  Medium
# Treatment
# No          31.03  34.15   34.82
# Yes         31.33  34.19   34.48
#
# Chi Stat: 0.4005 | P-Value: 0.819 | Degrees of Freedom: 2 | Expected Frequencies: [[3762.65 4524.35]
#  [4122.25 4956.75]
#  [4178.1  5023.9 ]]
#
# Treatment and HabitsChange by Percentage:
# Treatment       No   Yes
# HabitsChange
# Maybe         3926  4709
# No            3623  4385
# Yes           4514  5411
#
# HabitsChange  Maybe     No    Yes
# Treatment
# No            32.55  30.03  37.42
# Yes           32.46  30.23  37.30
#
# Chi Stat: 0.1218 | P-Value: 0.941 | Degrees of Freedom: 2 | Expected Frequencies: [[3920.66 4714.34]
#  [3635.97 4372.03]
#  [4506.37 5418.63]]
#
# Treatment and WorkInterest by Percentage:
# Treatment       No   Yes
# WorkInterest
# Maybe         4166  5019
# No            4396  5217
# Yes           3501  4269
#
# WorkInterest  Maybe     No    Yes
# Treatment
# No            34.54  36.44  29.02
# Yes           34.60  35.97  29.43
#
# Chi Stat: 0.7952 | P-Value: 0.672 | Degrees of Freedom: 2 | Expected Frequencies: [[4170.38 5014.62]
#  [4364.71 5248.29]
#  [3527.91 4242.09]]
#
# Treatment and CopingStruggles by Percentage:
# Treatment          No   Yes
# CopingStruggles
# No               6547  7742
# Yes              5516  6763
#
# CopingStruggles     No    Yes
# Treatment
# No               54.27  45.73
# Yes              53.37  46.63
#
# Chi Stat: 2.1039 | P-Value: 0.147 | Degrees of Freedom: 1 | Expected Frequencies: [[6487.81 7801.19]
#  [5575.19 6703.81]]
#
# MentalHealthInterview and IncreasingStress by Percentage:
# MentalHealthInterview  Maybe    No  Yes
# IncreasingStress
# Maybe                   2304  6620  379
# No                      2067  5970  337
# Yes                     2178  6359  354
#
# IncreasingStress       Maybe     No    Yes
# MentalHealthInterview
# Maybe                  35.18  31.56  33.26
# No                     34.94  31.51  33.56
# Yes                    35.42  31.50  33.08
#
# Chi Stat: 0.3213 | P-Value: 0.988 | Degrees of Freedom: 4 | Expected Frequencies: [[2293.19 6635.15  374.67]
#  [2064.19 5972.56  337.25]
#  [2191.63 6341.3   358.08]]
#
# MentalHealthInterview and SocialWeakness by Percentage:
# MentalHealthInterview  Maybe    No  Yes
# SocialWeakness
# Maybe                   2339  6785  386
# No                      2197  6339  359
# Yes                     2013  5825  325
#
# SocialWeakness         Maybe     No    Yes
# MentalHealthInterview
# Maybe                  35.72  33.55  30.74
# No                     35.81  33.45  30.74
# Yes                    36.07  33.55  30.37
#
# Chi Stat: 0.095 | P-Value: 0.999 | Degrees of Freedom: 4 | Expected Frequencies: [[2344.21 6782.78  383.01]
#  [2192.61 6344.15  358.24]
#  [2012.18 5822.07  328.76]]
#
# MentalHealthInterview and MoodSwings by Percentage:
# MentalHealthInterview  Maybe    No  Yes
# MoodSwings
# High                    2033  5919  335
# Low                     2242  6473  364
# Medium                  2274  6557  371
#
# MoodSwings              High    Low  Medium
# MentalHealthInterview
# Maybe                  31.04  34.23   34.72
# No                     31.24  34.16   34.60
# Yes                    31.31  34.02   34.67
#
# Chi Stat: 0.0994 | P-Value: 0.999 | Degrees of Freedom: 4 | Expected Frequencies: [[2042.74 5910.51  333.75]
#  [2237.97 6475.38  365.65]
#  [2268.29 6563.11  370.6 ]]
#
# MentalHealthInterview and HabitsChange by Percentage:
# MentalHealthInterview  Maybe    No  Yes
# HabitsChange
# Maybe                   2124  6161  350
# No                      1982  5706  320
# Yes                     2443  7082  400
#
# HabitsChange           Maybe     No    Yes
# MentalHealthInterview
# Maybe                  32.43  30.26  37.30
# No                     32.51  30.11  37.37
# Yes                    32.71  29.91  37.38
#
# Chi Stat: 0.0891 | P-Value: 0.999 | Degrees of Freedom: 4 | Expected Frequencies: [[2128.52 6158.71  347.77]
#  [1973.97 5711.52  322.51]
#  [2446.51 7078.77  399.72]]
#
# MentalHealthInterview and WorkInterest by Percentage:
# MentalHealthInterview  Maybe    No  Yes
# WorkInterest
# Maybe                   2277  6544  364
# No                      2367  6851  395
# Yes                     1905  5554  311
#
# WorkInterest           Maybe     No    Yes
# MentalHealthInterview
# Maybe                  34.77  36.14  29.09
# No                     34.53  36.15  29.31
# Yes                    34.02  36.92  29.07
#
# Chi Stat: 0.4358 | P-Value: 0.979 | Degrees of Freedom: 4 | Expected Frequencies: [[2264.1  6550.98  369.92]
#  [2369.6  6856.25  387.15]
#  [1915.3  5541.77  312.93]]
#
# MentalHealthInterview and CopingStruggles by Percentage:
# MentalHealthInterview  Maybe     No  Yes
# CopingStruggles
# No                      3527  10180  582
# Yes                     3022   8769  488
#
# CopingStruggles           No    Yes
# MentalHealthInterview
# Maybe                  53.86  46.14
# No                     53.72  46.28
# Yes                    54.39  45.61
#
# Chi Stat: 0.2011 | P-Value: 0.904 | Degrees of Freedom: 2 | Expected Frequencies: [[ 3522.23 10191.29   575.48]
#  [ 3026.77  8757.71   494.52]]
#
# ['Treatment and IncreasingStress', 'Treatment and SocialWeakness', 'Treatment and MoodSwings', 'Treatment and HabitsChange', 'Treatment and WorkInterest', 'Treatment and CopingStruggles', 'MentalHealthInterview and IncreasingStress', 'MentalHealthInterview and SocialWeakness', 'MentalHealthInterview and MoodSwings', 'MentalHealthInterview and HabitsChange', 'MentalHealthInterview and WorkInterest', 'MentalHealthInterview and CopingStruggles']
