# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Mental Health Problems: Mood Swings, Increasing Stress, Mental Health History, and Social Weakness
df = pd.read_csv('Mental_Health_dataset1.csv')
df
# Out:
#         Gender Country Occupation SelfEmployed FamilyHistory Treatment  \
# 0       Female      UK     Others           No           Yes        No
# 1       Female     USA  Housewife           No           Yes        No
# 2       Female  Canada     Others           No            No       Yes
# 3       Female  Canada  Corporate           No           Yes       Yes
# 4       Female      UK  Corporate           No            No       Yes
# ...        ...     ...        ...          ...           ...       ...
# 261323    Male     USA   Business           No            No        No
# 261324    Male     USA   Business          Yes           Yes       Yes
# 261325    Male     USA   Business           No           Yes        No
# 261326    Male     USA   Business           No           Yes       Yes
# 261327    Male     USA   Business           No           Yes       Yes
#
#                DaysIndoors HabitsChange MentalHealthHistory IncreasingStress  \
# 0               15-30 days           No                 Yes              Yes
# 1               15-30 days        Maybe               Maybe              Yes
# 2       More than 2 months        Maybe                  No               No
# 3         Go out Every day           No               Maybe               No
# 4       More than 2 months          Yes                  No            Maybe
# ...                    ...          ...                 ...              ...
# 261323          15-30 days        Maybe                  No               No
# 261324          15-30 days        Maybe                  No               No
# 261325          15-30 days        Maybe                  No               No
# 261326          15-30 days        Maybe                  No               No
# 261327          15-30 days        Maybe                  No               No
#
#        MoodSwings SocialWeakness CopingStruggles WorkInterest  \
# 0            High             No             Yes        Maybe
# 1            High          Maybe             Yes        Maybe
# 2          Medium             No              No           No
# 3          Medium             No              No        Maybe
# 4          Medium          Maybe              No        Maybe
# ...           ...            ...             ...          ...
# 261323        Low          Maybe             Yes           No
# 261324        Low          Maybe             Yes           No
# 261325        Low          Maybe             Yes           No
# 261326        Low          Maybe             Yes           No
# 261327        Low          Maybe             Yes           No
#
#        SocialWeakness.1 MentalHealthInterview CareOptions
# 0                    No                    No          No
# 1                 Maybe                    No    Not sure
# 2                    No                    No    Not sure
# 3                    No                    No    Not sure
# 4                 Maybe                    No    Not sure
# ...                 ...                   ...         ...
# 261323            Maybe                 Maybe    Not sure
# 261324            Maybe                 Maybe    Not sure
# 261325            Maybe                    No          No
# 261326            Maybe                    No         Yes
# 261327            Maybe                    No         Yes
#
# [261328 rows x 17 columns]

# %%
DaysIndoors = df['DaysIndoors'].unique()
Nationality = df['Country'].unique()
Occupation = df['Occupation'].unique()
MoodSwings = df['MoodSwings'].unique()
CareOptions = df['CareOptions'].unique()
#df['SocialWeakness'].compare(df['SocialWeakness.1']) # RM SocialWeakness.1
Occupation
# Out:
# array(['Others', 'Housewife', 'Corporate', 'Student', 'Business'],
#       dtype=object)

# %%
df['HabitsChange'].value_counts() # Treat maybes like a 0.5?
# Out:
# HabitsChange
# Yes      97687
# Maybe    85081
# No       78560
# Name: count, dtype: int64

# %%
df.drop('SocialWeakness.1', axis=1, inplace=True)

# %%
df
# Out:
#         Gender Country Occupation SelfEmployed FamilyHistory Treatment  \
# 0       Female      UK     Others           No           Yes        No
# 1       Female     USA  Housewife           No           Yes        No
# 2       Female  Canada     Others           No            No       Yes
# 3       Female  Canada  Corporate           No           Yes       Yes
# 4       Female      UK  Corporate           No            No       Yes
# ...        ...     ...        ...          ...           ...       ...
# 261323    Male     USA   Business           No            No        No
# 261324    Male     USA   Business          Yes           Yes       Yes
# 261325    Male     USA   Business           No           Yes        No
# 261326    Male     USA   Business           No           Yes       Yes
# 261327    Male     USA   Business           No           Yes       Yes
#
#                DaysIndoors HabitsChange MentalHealthHistory IncreasingStress  \
# 0               15-30 days           No                 Yes              Yes
# 1               15-30 days        Maybe               Maybe              Yes
# 2       More than 2 months        Maybe                  No               No
# 3         Go out Every day           No               Maybe               No
# 4       More than 2 months          Yes                  No            Maybe
# ...                    ...          ...                 ...              ...
# 261323          15-30 days        Maybe                  No               No
# 261324          15-30 days        Maybe                  No               No
# 261325          15-30 days        Maybe                  No               No
# 261326          15-30 days        Maybe                  No               No
# 261327          15-30 days        Maybe                  No               No
#
#        MoodSwings SocialWeakness CopingStruggles WorkInterest  \
# 0            High             No             Yes        Maybe
# 1            High          Maybe             Yes        Maybe
# 2          Medium             No              No           No
# 3          Medium             No              No        Maybe
# 4          Medium          Maybe              No        Maybe
# ...           ...            ...             ...          ...
# 261323        Low          Maybe             Yes           No
# 261324        Low          Maybe             Yes           No
# 261325        Low          Maybe             Yes           No
# 261326        Low          Maybe             Yes           No
# 261327        Low          Maybe             Yes           No
#
#        MentalHealthInterview CareOptions
# 0                         No          No
# 1                         No    Not sure
# 2                         No    Not sure
# 3                         No    Not sure
# 4                         No    Not sure
# ...                      ...         ...
# 261323                 Maybe    Not sure
# 261324                 Maybe    Not sure
# 261325                    No          No
# 261326                    No         Yes
# 261327                    No         Yes
#
# [261328 rows x 16 columns]
