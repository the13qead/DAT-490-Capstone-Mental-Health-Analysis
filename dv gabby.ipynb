# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.mixture import GaussianMixture
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("Mental Health dataset1.csv")

# %%
if "SocialWeakness.1" in df.columns:
    df = df.drop(columns=["SocialWeakness.1"])

df = df.dropna(subset=["SelfEmployed"])

# Basic gender cleaning
df["Gender"] = df["Gender"].astype(str).str.lower().str.strip()
df["Gender"] = df["Gender"].replace({
    "male": "male", "m": "male", "man": "male",
    "female": "female", "f": "female", "woman": "female"
})
df["Gender"] = df["Gender"].where(df["Gender"].isin(["male", "female"]), "other")

# %%
lca_features = ["Occupation", "Gender", "Country",
                "SelfEmployed", "FamilyHistory", "DaysIndoors"]


ct = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), lca_features)
    ],
    remainder="drop"
)

# %%
n_classes = 3  

lca_model = Pipeline(steps=[
    ("encoder", ct),
    ("gmm", GaussianMixture(n_components=n_classes, random_state=42))
])

lca_model.fit(df)


encoded = lca_model["encoder"].transform(df)
df["LatentClass"] = lca_model["gmm"].predict(encoded)

print("Latent Class Counts:")
print(df["LatentClass"].value_counts())
# Out:
# Latent Class Counts:
# LatentClass
# 1    147314
# 0     79688
# 2     29970
# Name: count, dtype: int64

# %%
outcomes = ["HabitsChange","MentalHealthHistory","IncreasingStress",
            "SocialWeakness","MoodSwings"]

def to_binary(col):
    col = col.astype(str).str.lower()
    return col.apply(lambda x: 
                     1 if x.startswith(("yes","y","often","high","frequent")) 
                     else 0)

for o in outcomes:
    df[o + "_bin"] = to_binary(df[o])

# %%
print("\n========== RQ2: OCCUPATION RISK WITHIN LATENT CLASSES ==========\n")

for c in sorted(df["LatentClass"].unique()):
    print(f"\n------ LATENT CLASS {c} ------")
    class_data = df[df["LatentClass"] == c]

    for o in outcomes:
        print(f"\nOutcome: {o}")
        risk = class_data.groupby("Occupation")[o + "_bin"].mean().sort_values(ascending=False)
        print(risk.head(10))
# Out:
# ========== RQ2: OCCUPATION RISK WITHIN LATENT CLASSES ==========
#
#
# ------ LATENT CLASS 0 ------
#
# Outcome: HabitsChange
# Occupation
# Others       0.420747
# Student      0.401754
# Housewife    0.379410
# Business     0.374321
# Corporate    0.309844
# Name: HabitsChange_bin, dtype: float64
#
# Outcome: MentalHealthHistory
# Occupation
# Others       0.376399
# Business     0.327748
# Housewife    0.303104
# Corporate    0.297496
# Student      0.287502
# Name: MentalHealthHistory_bin, dtype: float64
#
# Outcome: IncreasingStress
# Occupation
# Business     0.391606
# Corporate    0.379968
# Student      0.356188
# Housewife    0.270162
# Others       0.260632
# Name: IncreasingStress_bin, dtype: float64
#
# Outcome: SocialWeakness
# Occupation
# Housewife    0.357647
# Business     0.344505
# Corporate    0.298530
# Student      0.273396
# Others       0.246503
# Name: SocialWeakness_bin, dtype: float64
#
# Outcome: MoodSwings
# Occupation
# Student      0.470870
# Others       0.303931
# Business     0.266455
# Housewife    0.260447
# Corporate    0.250000
# Name: MoodSwings_bin, dtype: float64
#
# ------ LATENT CLASS 1 ------
#
# Outcome: HabitsChange
# Occupation
# Others       0.420776
# Student      0.402391
# Housewife    0.378986
# Business     0.375082
# Corporate    0.309863
# Name: HabitsChange_bin, dtype: float64
#
# Outcome: MentalHealthHistory
# Occupation
# Others       0.375937
# Business     0.328722
# Housewife    0.303212
# Corporate    0.297600
# Student      0.288505
# Name: MentalHealthHistory_bin, dtype: float64
#
# Outcome: IncreasingStress
# Occupation
# Business     0.391732
# Corporate    0.380584
# Student      0.356062
# Housewife    0.270208
# Others       0.261077
# Name: IncreasingStress_bin, dtype: float64
#
# Outcome: SocialWeakness
# Occupation
# Housewife    0.356807
# Business     0.344434
# Corporate    0.297973
# Student      0.275557
# Others       0.245853
# Name: SocialWeakness_bin, dtype: float64
#
# Outcome: MoodSwings
# Occupation
# Student      0.469716
# Others       0.304590
# Business     0.266079
# Housewife    0.260442
# Corporate    0.250039
# Name: MoodSwings_bin, dtype: float64
#
# ------ LATENT CLASS 2 ------
#
# Outcome: HabitsChange
# Occupation
# Business     0.424677
# Housewife    0.372446
# Corporate    0.365657
# Student      0.337163
# Others       0.315426
# Name: HabitsChange_bin, dtype: float64
#
# Outcome: MentalHealthHistory
# Occupation
# Others       0.347255
# Housewife    0.335637
# Corporate    0.288946
# Business     0.278757
# Student      0.278686
# Name: MentalHealthHistory_bin, dtype: float64
#
# Outcome: IncreasingStress
# Occupation
# Others       0.418659
# Housewife    0.417518
# Corporate    0.400275
# Student      0.376049
# Business     0.375068
# Name: IncreasingStress_bin, dtype: float64
#
# Outcome: SocialWeakness
# Occupation
# Business     0.351990
# Others       0.336477
# Student      0.317425
# Corporate    0.305862
# Housewife    0.272987
# Name: SocialWeakness_bin, dtype: float64
#
# Outcome: MoodSwings
# Occupation
# Housewife    0.365986
# Corporate    0.359166
# Others       0.342540
# Business     0.323642
# Student      0.311681
# Name: MoodSwings_bin, dtype: float64

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Mental Health dataset1.csv") 

# Remove duplicate SocialWeakness column if it exists
if "SocialWeakness.1" in df.columns:
    df = df.drop(columns=["SocialWeakness.1"])

# Drop rows with missing SelfEmployed 
df = df.dropna(subset=["SelfEmployed"])

# Clean Gender into male / female / other
df["Gender"] = df["Gender"].astype(str).str.lower().str.strip()
df["Gender"] = df["Gender"].replace({
    "male": "male", "m": "male", "man": "male",
    "female": "female", "f": "female", "woman": "female"
})
df["Gender"] = df["Gender"].where(df["Gender"].isin(["male", "female"]), "other")

# %%
lca_features = ["Occupation", "Gender", "Country",
                "SelfEmployed", "FamilyHistory", "DaysIndoors"]


ct = ColumnTransformer(
    transformers=[("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), lca_features)]
)


n_classes = 3

lca_model = Pipeline(steps=[
    ("encoder", ct),
    ("gmm", GaussianMixture(n_components=n_classes, random_state=42))
])


lca_model.fit(df)
encoded = lca_model["encoder"].transform(df)
df["LatentClass"] = lca_model["gmm"].predict(encoded)

print("Latent class counts:")
print(df["LatentClass"].value_counts())
# Out:
# Latent class counts:
# LatentClass
# 1    147314
# 0     79688
# 2     29970
# Name: count, dtype: int64

# %%
outcomes = ["HabitsChange",
            "MentalHealthHistory",
            "IncreasingStress",
            "SocialWeakness",
            "MoodSwings"]

def to_binary(col):
    col = col.astype(str).str.lower()
    return col.apply(
        lambda x: 1 if x.startswith(("yes", "y", "often", "high", "frequent"))
        else 0
    )

for o in outcomes:
    df[o + "_bin"] = to_binary(df[o])

# %%
for c in sorted(df["LatentClass"].unique()):
    class_data = df[df["LatentClass"] == c]

    for o in outcomes:
        o_bin = o + "_bin"
       
        risk = (
            class_data.groupby("Occupation")[o_bin]
            .mean()
            .sort_values(ascending=False)
            .head(10)   # top 10 occupations
        )

      
        if risk.empty:
            continue

        plt.figure(figsize=(8, 5))
        plt.barh(risk.index, risk.values)
        plt.gca().invert_yaxis()  # highest at top
        plt.xlabel("Proportion with mental health issue")
        plt.title(f"Top 10 Occupations for {o} in Latent Class {c}")
        plt.tight_layout()
        plt.show()

# %%
vars_to_plot = [
    "HabitsChange_bin",
    "IncreasingStress_bin",
    "SocialWeakness_bin",
    "MoodSwings_bin",
    "MentalHealthHistory_bin"
]


var_labels = [
    "Habits change",
    "Increasing stress",
    "Social weakness",
    "Mood swings",
    "Mental health history"
]
scale_factor = 5.0

# %%
class_counts = df["LatentClass"].value_counts(normalize=True).sort_index()

class_labels = [
    f"Class {i+1}, {p*100:.1f}%"
    for i, p in class_counts.items()
]

# %%
classes = sorted(df["LatentClass"].unique())
mean_matrix = []

for c in classes:
    sub = df[df["LatentClass"] == c]
    means = sub[vars_to_plot].mean() * scale_factor   
    mean_matrix.append(means.values)

mean_matrix = np.array(mean_matrix)

# %%
x = range(len(var_labels)) 

var_groups = ["Group A"] * len(var_labels)  


markers = ["o", "s", "v"]  
linestyles = ["-", "--", "-."]

for i, c in enumerate(classes):
    plt.plot(
        x,
        mean_matrix[i],
        marker=markers[i % len(markers)],
        linestyle=linestyles[i % len(linestyles)],
        label=class_labels[i]
    )

plt.xticks(x, var_labels, rotation=60, ha="right")
plt.ylabel("Mean Score (0–5)")
plt.ylim(0, 5.5)


if var_groups:
    last_group = var_groups[0]
    for idx in range(1, len(var_groups)):
        if var_groups[idx] != last_group:
            plt.axvline(x=idx-0.5, color="grey", linestyle=":", linewidth=1)
            last_group = var_groups[idx]

 
    group_positions = {}
    for idx, g in enumerate(var_groups):
        group_positions.setdefault(g, []).append(idx)

    y_min = plt.ylim()[0]
    for g, idxs in group_positions.items():
        mid = (min(idxs) + max(idxs)) / 2
        plt.text(mid, y_min - 0.4, g, ha="center", va="top")

plt.title("Latent Class Profiles of Mental Health and Behaviors")
plt.legend()
plt.tight_layout()
plt.show()
